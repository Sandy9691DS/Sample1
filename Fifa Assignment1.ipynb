# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
f = pd.read_csv('https://raw.githubusercontent.com/hakimyameen/Datasets/main/fifa_eda.csv')
f.head(3)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0

# %%
#Groupby using pandas - for categorical data

# %%
#Select categorical data = object
f.select_dtypes('object')
# Out:
#                      Name Nationality                 Club Preferred Foot  \
# 0                L. Messi   Argentina         FC Barcelona           Left
# 1       Cristiano Ronaldo    Portugal             Juventus          Right
# 2               Neymar Jr      Brazil  Paris Saint-Germain          Right
# 3                  De Gea       Spain    Manchester United          Right
# 4            K. De Bruyne     Belgium      Manchester City          Right
# ...                   ...         ...                  ...            ...
# 18202        J. Lundstram     England      Crewe Alexandra          Right
# 18203  N. Christoffersson      Sweden       Trelleborgs FF          Right
# 18204           B. Worman     England     Cambridge United          Right
# 18205      D. Walker-Rice     England      Tranmere Rovers          Right
# 18206           G. Nugent     England      Tranmere Rovers          Right
#
#       Position Contract Valid Until
# 0           RF           2021-01-01
# ...

# %%
# How to perform Groupby operation
f.groupby('Nationality')

# %%
# Lets typecast to see groupings
list(f.groupby('Nationality'))

#when we perform a groupby, it gives 2 things
#tuple (Category,data)
# Out:
# [('Afghanistan',
#              ID        Name  Age  Nationality  Overall  Potential  \
#   12891  244175     H. Amin   26  Afghanistan       63         64
#   13644  233128  M. Kouhyar   20  Afghanistan       62         70
#   15273  223989    N. Husin   21  Afghanistan       60         71
#   15534  237682    A. Najem   23  Afghanistan       59         66
#
#                        Club  Value  Wage Preferred Foot  \
#   12891           SV Meppen  350.0   1.0           Left
#   13644             Walsall  450.0   1.0          Right
#   15273        Notts County  350.0   2.0          Right
#   15534  Philadelphia Union  220.0   1.0          Right
#
#          International Reputation  Skill Moves Position  Joined  \
#   12891                       1.0          3.0       LB    2018
#   13644                       1.0          3.0       LM    2016
#   15273                       1.0          2.0       CM    2018
#   15534                       1.0          2.0      CAM    2017
#
# ...

# %%
#If you want to get a data of perticular category
f.groupby('Nationality').get_group('India') #This will return data(dataframe)
# Out:
#            ID             Name  Age Nationality  Overall  Potential Club  \
# 8605   190939       S. Chhetri   33       India       67         67  NaN
# 10011  223763       S. Jhingan   24       India       65         71  NaN
# 12598  217225    J. Lalpekhlua   27       India       63         64  NaN
# 12811  225213  G. Singh Sandhu   26       India       63         68  NaN
# 13508  238205    A. Edathodika   31       India       62         62  NaN
# 14054  231461        P. Halder   25       India       61         67  NaN
# 14199  228188         P. Kotal   24       India       61         66  NaN
# 14218  208485         L. Ralte   25       India       61         62  NaN
# 14705  223764           N. Das   24       India       60         65  NaN
# 14786  233524         U. Singh   22       India       60         67  NaN
# 14915  228199       H. Narzary   24       India       60         66  NaN
# 15356  212502         R. Singh   28       India       59         59  NaN
# ...

# %%
#check unique nationality
f.Nationality.unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
# Fetch first record of each country
f.groupby('Nationality').first()
# Out:
#                  ID          Name  Age  Overall  Potential  \
# Nationality
# Afghanistan  244175       H. Amin   26       63         64
# Albania      212151  T. Strakosha   23       81         86
# Algeria      204485     R. Mahrez   27       85         85
# Andorra      192937    Marc Vales   28       62         64
# Angola       216655        Bastos   26       78         79
# ...             ...           ...  ...      ...        ...
# Uzbekistan   181573   O. Akhmedov   30       75         75
# Venezuela    207877   J. Martínez   25       81         84
# Wales        173731       G. Bale   28       88         88
# Zambia       190276      S. Sunzu   29       73         74
# Zimbabwe     222994    M. Nakamba   24       78         83
#
#                            Club    Value   Wage Preferred Foot  \
# Nationality
# Afghanistan           SV Meppen    350.0    1.0           Left
# Albania                   Lazio  17000.0   36.0          Right
# ...

# %%
# Fetch last record of each country
f.groupby('Nationality').last() #final match record fetching
# Out:
#                  ID         Name  Age  Overall  Potential                Club  \
# Nationality
# Afghanistan  237682     A. Najem   23       59         66  Philadelphia Union
# Albania      234896    B. Bytyqi   21       52         63          Aalborg BK
# Algeria      212063   A. Gafaiti   23       58         66         Yeovil Town
# Andorra      192937   Marc Vales   28       62         64  Sandefjord Fotball
# Angola       239267    A. Pululu   19       60         76       FC Basel 1893
# ...             ...          ...  ...      ...        ...                 ...
# Uzbekistan   197597    F. Musaev   29       60         60        Júbilo Iwata
# Venezuela    242463  F. Figueroa   20       53         66      Atlético Huila
# Wales        240927   L. Collins   17       47         62      Newport County
# Zambia       242612  E. Chilufya   18       56         75      Djurgårdens IF
# Zimbabwe     235432   M. Munetsi   22       64         71     Orlando Pirates
#
# ...

# %%
# Fetch last record of each country
#f.groupby('Nationality').last()
f.groupby('Nationality').last()[['Name','Club']]
# Out:
#                     Name                Club
# Nationality
# Afghanistan     A. Najem  Philadelphia Union
# Albania        B. Bytyqi          Aalborg BK
# Algeria       A. Gafaiti         Yeovil Town
# Andorra       Marc Vales  Sandefjord Fotball
# Angola         A. Pululu       FC Basel 1893
# ...                  ...                 ...
# Uzbekistan     F. Musaev        Júbilo Iwata
# Venezuela    F. Figueroa      Atlético Huila
# Wales         L. Collins      Newport County
# Zambia       E. Chilufya      Djurgårdens IF
# Zimbabwe      M. Munetsi     Orlando Pirates
#
# [164 rows x 2 columns]

# %%
f[['Nationality','Preferred Foot']]
# Out:
#       Nationality Preferred Foot
# 0       Argentina           Left
# 1        Portugal          Right
# 2          Brazil          Right
# 3           Spain          Right
# 4         Belgium          Right
# ...           ...            ...
# 18202     England          Right
# 18203      Sweden          Right
# 18204     England          Right
# 18205     England          Right
# 18206     England          Right
#
# [18207 rows x 2 columns]

# %%
f[['Nationality','Preferred Foot']].describe() #Statistical data
# Out:
#        Nationality Preferred Foot
# count        18207          18207
# unique         164              2
# top        England          Right
# freq          1662          13996

# %%
#lets use 2 columns with groupby
list(f.groupby(['Nationality','Preferred Foot']))
# Out:
# [(('Afghanistan', 'Left'),
#              ID     Name  Age  Nationality  Overall  Potential       Club  \
#   12891  244175  H. Amin   26  Afghanistan       63         64  SV Meppen
#
#          Value  Wage Preferred Foot  International Reputation  Skill Moves  \
#   12891  350.0   1.0           Left                       1.0          3.0
#
#         Position  Joined Contract Valid Until  Height  Weight  Release Clause
#   12891       LB    2018           2020-01-01    5.75   152.0           534.0  ),
#  (('Afghanistan', 'Right'),
#              ID        Name  Age  Nationality  Overall  Potential  \
#   13644  233128  M. Kouhyar   20  Afghanistan       62         70
#   15273  223989    N. Husin   21  Afghanistan       60         71
#   15534  237682    A. Najem   23  Afghanistan       59         66
#
#                        Club  Value  Wage Preferred Foot  \
#   13644             Walsall  450.0   1.0          Right
#   15273        Notts County  350.0   2.0          Right
# ...

# %%
f.groupby(['Nationality','Preferred Foot']).Age.mean()
# Out:
# Nationality  Preferred Foot
# Afghanistan  Left              26.000000
#              Right             21.333333
# Albania      Left              25.111111
#              Right             23.709677
# Algeria      Left              26.450000
#                                  ...
# Wales        Right             24.495050
# Zambia       Left              20.000000
#              Right             22.500000
# Zimbabwe     Left              26.800000
#              Right             26.875000
# Name: Age, Length: 287, dtype: float64

# %%
#aggregate opertions
f.groupby('Nationality').Age.agg(max)
# Out:
# Nationality
# Afghanistan    26
# Albania        34
# Algeria        35
# Andorra        28
# Angola         34
#                ..
# Uzbekistan     30
# Venezuela      34
# Wales          37
# Zambia         29
# Zimbabwe       34
# Name: Age, Length: 164, dtype: int64

# %%
f.groupby('Nationality').Age.agg(min)
# Out:
# Nationality
# Afghanistan    20
# Albania        18
# Algeria        19
# Andorra        28
# Angola         19
#                ..
# Uzbekistan     29
# Venezuela      18
# Wales          17
# Zambia         18
# Zimbabwe       22
# Name: Age, Length: 164, dtype: int64

# %%
f.groupby('Nationality')[['Age','Wage']].agg(max)
# Out:
#              Age   Wage
# Nationality
# Afghanistan   26    2.0
# Albania       34   58.0
# Algeria       35  205.0
# Andorra       28    1.0
# Angola        34   44.0
# ...          ...    ...
# Uzbekistan    30   17.0
# Venezuela     34   42.0
# Wales         37  355.0
# Zambia        29    7.0
# Zimbabwe      34   27.0
#
# [164 rows x 2 columns]

# %%
#Can we apply more agg funtions
f.groupby('Nationality')[['Age','Wage']].agg([max,min,np.mean])
# Out:
#             Age                  Wage
#             max min       mean    max  min       mean
# Nationality
# Afghanistan  26  20  22.500000    2.0  1.0   1.250000
# Albania      34  18  24.025000   58.0  1.0   7.100000
# Algeria      35  19  27.050000  205.0  1.0  18.083333
# Andorra      28  28  28.000000    1.0  1.0   1.000000
# Angola       34  19  25.866667   44.0  1.0   7.666667
# ...          ..  ..        ...    ...  ...        ...
# Uzbekistan   30  29  29.500000   17.0  1.0   9.000000
# Venezuela    34  18  24.313433   42.0  0.0   6.194030
# Wales        37  17  24.736434  355.0  0.0  12.093023
# Zambia       29  18  22.222222    7.0  1.0   3.444444
# Zimbabwe     34  22  26.846154   27.0  1.0   6.846154
#
# [164 rows x 6 columns]

# %%
f.groupby('Nationality').first().sort_values(by='Joined')
# Out:
#                  ID          Name  Age  Overall  Potential  \
# Nationality
# Argentina    158023      L. Messi   31       94         94
# Italy        138956  G. Chiellini   33       89         89
# Kuwait       219106  F. Al Ansari   31       70         70
# Slovakia     171877     M. Hamšík   30       87         87
# Romania      165109       S. Radu   31       80         80
# ...             ...           ...  ...      ...        ...
# Rwanda       243339   D. Bizimana   21       63         71
# Estonia      140620     R. Klavan   32       77         77
# El Salvador  217217      D. Cerén   28       70         70
# DR Congo     198951    C. Bakambu   27       82         83
# Afghanistan  244175       H. Amin   26       63         64
#
#                                 Club     Value   Wage Preferred Foot  \
# Nationality
# Argentina               FC Barcelona  110500.0  565.0           Left
# Italy                       Juventus   27000.0  215.0           Left
# ...

# %%
fs = f.groupby('Nationality').first()
fs.sort_values(by='Joined')
# Out:
#                  ID          Name  Age  Overall  Potential  \
# Nationality
# Argentina    158023      L. Messi   31       94         94
# Italy        138956  G. Chiellini   33       89         89
# Kuwait       219106  F. Al Ansari   31       70         70
# Slovakia     171877     M. Hamšík   30       87         87
# Romania      165109       S. Radu   31       80         80
# ...             ...           ...  ...      ...        ...
# Rwanda       243339   D. Bizimana   21       63         71
# Estonia      140620     R. Klavan   32       77         77
# El Salvador  217217      D. Cerén   28       70         70
# DR Congo     198951    C. Bakambu   27       82         83
# Afghanistan  244175       H. Amin   26       63         64
#
#                                 Club     Value   Wage Preferred Foot  \
# Nationality
# Argentina               FC Barcelona  110500.0  565.0           Left
# Italy                       Juventus   27000.0  215.0           Left
# ...

# %%
#Assignment = remove space between column labels and add _
#2nd = Remove ID column
#3rd = Display the data of FC Barcelona
#4th = Feth players whose age > 30 and count how many are there
#5th = pei plot for Preferred foor and give your analysis
#6th = select players from Germany whose age is < 20
#7th = select players whose Value > 50000 and < 110000
#8th = select players with skill moves = 5.0
#9th = fetch record of Neymar Jr
#10th = Check countrywise average height and weight of players
f.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %%
#remove space between column labels and add _
f.columns = f.columns.str.replace (' ','_')
f.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred_Foot', 'International_Reputation',
#        'Skill_Moves', 'Position', 'Joined', 'Contract_Valid_Until', 'Height',
#        'Weight', 'Release_Clause'],
#       dtype='object')

# %%
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred_Foot  \
# ...

# %%
#2nd = Remove ID column
f.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Preferred_Foot', 'International_Reputation', 'Skill_Moves',
#        'Position', 'Joined', 'Contract_Valid_Until', 'Height', 'Weight',
#        'Release_Clause'],
#       dtype='object')

# %%
#3rd = Display the data of FC Barcelona
fcb = f.query('Club=="FC Barcelona"').sort_values('Overall',ascending=False)
fcb
# Out:
#                   Name  Age  Nationality  Overall  Potential          Club  \
# 0             L. Messi   31    Argentina       94         94  FC Barcelona
# 7            L. Suárez   31      Uruguay       91         91  FC Barcelona
# 18       M. ter Stegen   26      Germany       89         92  FC Barcelona
# 20     Sergio Busquets   29        Spain       89         89  FC Barcelona
# 32            Coutinho   26       Brazil       88         89  FC Barcelona
# 42           S. Umtiti   24       France       87         92  FC Barcelona
# 49          Jordi Alba   29        Spain       87         87  FC Barcelona
# 53          I. Rakitić   30      Croatia       87         87  FC Barcelona
# 54               Piqué   31        Spain       87         87  FC Barcelona
# 96            A. Vidal   31        Chile       85         85  FC Barcelona
# 155         O. Dembélé   21       France       83         92  FC Barcelona
# ...

# %%
#4th = Fetch players whose age > 30 and count how many are there
a = f.query('Age > 30')
a.shape[0]
# Out:
# 2582

# %%
ft = f.Preferred_Foot.value_counts()
ft
# Out:
# Right    13996
# Left      4211
# Name: Preferred_Foot, dtype: int64

# %%
#5th = pie plot for Preferred foot and give your analysis
ft.plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='Preferred_Foot'>

# %% [markdown]
# Analysis:
#
# 1- From the pie chart we can say that 76.87% i.e 13996 players preferred right foot which is in blue color.
#
# 2- and 23.13% i.e 4211 players preferred left foot to play that we can see in orange color.

# %%
#6th = select players from Germany whose age is < 20
ger = f.query('Nationality == "Germany" and Age < 20')
ger
# Out:
#              Name  Age Nationality  Overall  Potential                   Club  \
# 413    K. Havertz   19     Germany       80         89    Bayer 04 Leverkusen
# 2743     A. Maier   19     Germany       73         86             Hertha BSC
# 6032       J. Arp   18     Germany       69         88           Hamburger SV
# 6833     L. Maina   19     Germany       68         81            Hannover 96
# 6936   F. Muslija   19     Germany       68         79            Hannover 96
# ...           ...  ...         ...      ...        ...                    ...
# 18101   J. Hipper   19     Germany       50         59       TSV 1860 München
# 18127  N. Stephan   17     Germany       49         67  FC Würzburger Kickers
# 18145  M. Harsman   18     Germany       49         65              SV Meppen
# 18187   C. Ehlich   19     Germany       47         59     SpVgg Unterhaching
# 18189  A. Kaltner   18     Germany       47         61     SpVgg Unterhaching
#
# ...

# %%
#7th = select players whose Value > 50000 and < 110000
fs = f.query('Value>50000 and Value<110000')
fs
# Out:
#                    Name  Age Nationality  Overall  Potential  \
# 1     Cristiano Ronaldo   33    Portugal       94         94
# 3                De Gea   27       Spain       91         93
# 4          K. De Bruyne   27     Belgium       91         92
# 5             E. Hazard   27     Belgium       91         91
# 6             L. Modrić   32     Croatia       91         91
# 7             L. Suárez   31     Uruguay       91         91
# 8          Sergio Ramos   32       Spain       91         91
# 9              J. Oblak   25    Slovenia       90         93
# 10       R. Lewandowski   29      Poland       90         90
# 11             T. Kroos   28     Germany       90         90
# 13          David Silva   32       Spain       90         90
# 14             N. Kanté   27      France       89         90
# 15            P. Dybala   24   Argentina       89         94
# 16              H. Kane   24     England       89         91
# ...

# %%
#8th = select players with skill moves = 5.0
sk = f.query('Skill_Moves==5.0')
sk
# Out:
#                    Name  Age           Nationality  Overall  Potential  \
# 1     Cristiano Ronaldo   33              Portugal       94         94
# 2             Neymar Jr   26                Brazil       92         93
# 25            K. Mbappé   19                France       88         95
# 32             Coutinho   26                Brazil       88         89
# 35              Marcelo   30                Brazil       88         88
# 45             P. Pogba   25                France       87         91
# 65        Douglas Costa   27                Brazil       86         86
# 67               Thiago   27                 Spain       86         86
# 84            R. Mahrez   27               Algeria       85         85
# 109      Z. Ibrahimović   36                Sweden       85         85
# 124            M. Depay   24           Netherlands       84         89
# 129         J. Cuadrado   30              Colombia       84         84
# ...

# %%
#9th = fetch record of Neymar Jr
N = f.query('Name=="Neymar Jr"')
N
# Out:
#         Name  Age Nationality  Overall  Potential                 Club  \
# 2  Neymar Jr   26      Brazil       92         93  Paris Saint-Germain
#
#       Value   Wage Preferred_Foot  International_Reputation  Skill_Moves  \
# 2  118500.0  290.0          Right                       5.0          5.0
#
#   Position  Joined Contract_Valid_Until  Height  Weight  Release_Clause
# 2       LW    2017           2022-01-01    5.75   150.0        228100.0

# %%
#10th = Check countrywise average height and weight of players
HW = f.groupby(['Nationality'])[['Height','Weight']].mean()
HW
# Out:
#                Height      Weight
# Nationality
# Afghanistan  5.729167  149.250000
# Albania      5.950753  164.424478
# Algeria      5.947222  167.250000
# Andorra      6.000000  174.000000
# Angola       5.877778  166.533333
# ...               ...         ...
# Uzbekistan   5.958333  164.000000
# Venezuela    5.894728  164.671330
# Wales        5.960594  166.403101
# Zambia       5.907407  162.000000
# Zimbabwe     5.852564  164.000000
#
# [164 rows x 2 columns]
